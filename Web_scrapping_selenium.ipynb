# %% [markdown]
# <a href="https://colab.research.google.com/github/moatazkrimchi/Web_scrapping/blob/main/Web_scrapping_selenium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# installer selenium et chromedriver
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# chromium-chromedriver is already the newest version (95.0.4638.69-0ubuntu0.18.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# ...

# %%
from selenium import webdriver
import pandas as pd
options = webdriver.ChromeOptions()
options.add_argument('-headless') 
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')

# %%
driver = webdriver.Chrome('chromedriver',options=options)
driver.get('https://www.youtube.com/channel/UCiDy_8ig36GuMQ1FCYIv_6w/videos')

# %%
chaine_titre = driver.find_elements_by_xpath('//*[@id="video-title"]')
chaine_vue = driver.find_elements_by_xpath('//*[@id="metadata-line"]/span[1]')
chaine_date = driver.find_elements_by_xpath('//*[@id="metadata-line"]/span[2]')


videos = []

for i in range(len(chaine_titre)):
  video_info={}
  video_info['titre'] = chaine_titre[i].text
  video_info['vue'] = chaine_vue[i].text
  video_info['date'] = chaine_date[i].text
  videos.append(video_info)
videos
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# [{'date': '1 month ago',
#   'titre': 'Comprendre les métiers data populaires: Data scientist vs analyst vs engineer',
#   'vue': '1.7K views'},
#  {'date': '2 months ago',
#   'titre': "Les bases de la statistique (Partie 8): L'hypothèse Null et l'hypothèse alternative",
#   'vue': '912 views'},
#  {'date': '2 months ago',
# ...

# %%
df = pd.DataFrame(videos,columns=['titre','vue','date'])
df
# Out:
#                                                 titre         vue          date
# 0   Comprendre les métiers data populaires: Data s...  1.7K views   1 month ago
# 1   Les bases de la statistique (Partie 8): L'hypo...   912 views  2 months ago
# 2   Les bases de la statistique (Partie 7): La dis...   930 views  2 months ago
# 3   Les bases de la statistique (Partie 6): C'est ...    1K views  2 months ago
# 4   Les bases de la statistique (Partie 5): C'est ...   943 views  2 months ago
# 5   Les bases de la statistique (Partie 4): L'hist...   781 views  2 months ago
# 6   Les bases de la statistique (Partie 3): L'écar...   946 views  2 months ago
# 7   Les bases de la statistique (partie 2): Compre...   920 views  2 months ago
# 8   Les bases de la statistique (partie 1): Les ty...  1.6K views  2 months ago
# 9   Projet en data analysis: Comment analyser les ...   988 views  3 months ago
# 10  Projet en data analysis: Comment analyser les ...   888 views  3 months ago
# ...

# %%
df.to_csv('formasys.csv')
